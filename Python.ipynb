# %%
print("Olá Mundo")
# Out:
# Olá Mundo

# %%
print("Estou aprendendo Python")
# Out:
# Estou aprendendo Python

# %%
"Estou aprendendo Python"
# Out:
# 'Estou aprendendo Python'

# %%
"Shitf + Enter - Compila e já cria uma nova linha de Código"
# Out:
# 'Shitf + Enter - Compila e já cria uma nova linha de Código'

# %%
1 + 1
# Out:
# 2

# %%
10 - 2
# Out:
# 8

# %%
#Esse é um comentário em Python

# %%
#Multiplicação
2 * 2
# Out:
# 4

# %%
#Divisão
10 / 2
# Out:
# 5.0

# %%
#Criar variáveis
a = 4
b = 6

# %%
a + b
# Out:
# 10

# %%
#Criando variável do tipo String
fase = "Python para análise de dados"

# %%
frase[0]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-ea222c82036a> in <module>
# ----> 1 frase[0]
#
# NameError: name 'frase' is not defined

# %%
fase[0]
# Out:
# 'P'

# %%
fase[0:10]
# Out:
# 'Python par'

# %%
fase[10:]
# Out:
# 'a análise de dados'

# %%
fase[::17]
# Out:
# 'Ps'

# %%
fase.count("dados")
# Out:
# 1

# %%
fase.lower()
# Out:
# 'python para análise de dados'

# %%
fase.upper()
# Out:
# 'PYTHON PARA ANÁLISE DE DADOS'

# %%
fase.replace("fase","Python")
# Out:
# 'Python para análise de dados'

# %%
fase.replace("Python","Frases")
# Out:
# 'Frases para análise de dados'

# %%
#Criando uma lista
animais = [1,2,3]
animais
# Out:
# [1, 2, 3]

# %%
animais = ["cachorro, "gato", 12345, 4.5]
# Out:
#   File "<ipython-input-24-f81d5d32d4c9>", line 1
#     animais = ["cachorro, "gato", 12345, 4.5]
#                               ^
# SyntaxError: invalid syntax

# %%
animais = ["cachorro", "gato", 12345, 4.5]

# %%
animais
# Out:
# ['cachorro', 'gato', 12345, 4.5]

# %%
animais[1]
# Out:
# 'gato'

# %%
animais[0] = "papagaio"
animais
# Out:
# ['papagaio', 'gato', 12345, 4.5]

# %%
animais.remove("gato")

# %%
animais
# Out:
# ['papagaio', 12345, 4.5]

# %%
gato in animais
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-31-0b5115355d3e> in <module>
# ----> 1 gato in animais
#
# NameError: name 'gato' is not defined

# %%
"gato" in animais
# Out:
# False

# %%
len(animais)
# Out:
# 3

# %%
lista = [100, 20, 80, 60, 40]

# %%
max(lista)
# Out:
# 100

# %%
min(lista)
# Out:
# 20

# %%
animais.append("leão")
animais
# Out:
# ['papagaio', 12345, 4.5, 'leão']

# %%
animais.extend(["cobra", 1])
animais
# Out:
# ['papagaio', 12345, 4.5, 'leão', 'cobra', 1]

# %%
animais.count("cachorro")
# Out:
# 0

# %%
lista.sort()

# %%
lista
# Out:
# [20, 40, 60, 80, 100]

# %%
#Tuplas

# %%
tp = ("Banana", "Maçã", 10, 50)

# %%
tp[0]
# Out:
# 'Banana'

# %%
#Tuplas são imutáveis, não permitem alterações

# %%
tp[0] = "laranja"
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-47-a103dc83a21e> in <module>
# ----> 1 tp[0] = "laranja"
#
# TypeError: 'tuple' object does not support item assignment

# %%
tp.count("Maçã")
# Out:
# 1

# %%
tp[0:2]
# Out:
# ('Banana', 'Maçã')

# %%
#Dicionário

# %%
dc = {"Maçã":20, "Banana":10, "Laranja":15}
dc['Maçã']
# Out:
# 20

# %%
dc[Maçã] = 25
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-53-359f3a91bad3> in <module>
# ----> 1 dc[Maçã] = 25
#
# NameError: name 'Maçã' is not defined

# %%
dc['Maçã'] = 25
dc
# Out:
# {'Maçã': 25, 'Banana': 10, 'Laranja': 15}

# %%
dc.keys()
# Out:
# dict_keys(['Maçã', 'Banana', 'Laranja'])

# %%
dc.values()
# Out:
# dict_values([25, 10, 15])

# %%
dc.setdefault("Limão", 22)
#Verfiique se tem o valor, se não tiver tiver ele adiciona
# Out:
# 22

# %%
dc
# Out:
# {'Maçã': 25, 'Banana': 10, 'Laranja': 15, 'Limão': 22}
